# %%
import pandas as pd
import numpy as np

# %%
finallist=[]
import xml.etree.ElementTree as ET
tree=ET.parse('bc-cnn-00-cnn_0001-part000_auto_conll_words.xml')
root= tree.getroot()
part000list=[]
for child in root:
    part000list.append(child.text)
finallist=finallist+part000list

tree=ET.parse('bc-cnn-00-cnn_0001-part001_auto_conll_words.xml')
root= tree.getroot()
part000list=[]
for child in root:
    part000list.append(child.text)
finallist=finallist+part000list

tree=ET.parse('bc-cnn-00-cnn_0001-part002_auto_conll_words.xml')
root= tree.getroot()
part000list=[]
for child in root:
    part000list.append(child.text)
finallist=finallist+part000list

tree=ET.parse('bc-cnn-00-cnn_0001-part003_auto_conll_words.xml')
root= tree.getroot()
part000list=[]
for child in root:
    part000list.append(child.text)
finallist=finallist+part000list

tree=ET.parse('bc-cnn-00-cnn_0001-part004_auto_conll_words.xml')
root= tree.getroot()
part000list=[]
for child in root:
    part000list.append(child.text)
finallist=finallist+part000list

tree=ET.parse('bc-cnn-00-cnn_0001-part005_auto_conll_words.xml')
root= tree.getroot()
part000list=[]
for child in root:
    part000list.append(child.text)
finallist=finallist+part000list

tree=ET.parse('bc-cnn-00-cnn_0001-part006_auto_conll_words.xml')
root= tree.getroot()
part000list=[]
for child in root:
    part000list.append(child.text)
finallist=finallist+part000list

tree=ET.parse('bc-cnn-00-cnn_0001-part007_auto_conll_words.xml')
root= tree.getroot()
part000list=[]
for child in root:
    part000list.append(child.text)
finallist=finallist+part000list

tree=ET.parse('bc-cnn-00-cnn_0001-part008_auto_conll_words.xml')
root= tree.getroot()
part000list=[]
for child in root:
    part000list.append(child.text)
finallist=finallist+part000list

tree=ET.parse('bc-cnn-00-cnn_0001-part009_auto_conll_words.xml')
root= tree.getroot()
part000list=[]
for child in root:
    part000list.append(child.text)
finallist=finallist+part000list


tree=ET.parse('bc-cnn-00-cnn_0001-part010_auto_conll_words.xml')
root= tree.getroot()
part000list=[]
for child in root:
    part000list.append(child.text)
finallist=finallist+part000list

tree=ET.parse('bc-cnn-00-cnn_0001-part011_auto_conll_words.xml')
root= tree.getroot()
part000list=[]
for child in root:
    part000list.append(child.text)
finallist=finallist+part000list

tree=ET.parse('bc-cnn-00-cnn_0001-part012_auto_conll_words.xml')
root= tree.getroot()
part000list=[]
for child in root:
    part000list.append(child.text)
finallist=finallist+part000list

tree=ET.parse('bc-cnn-00-cnn_0001-part013_auto_conll_words.xml')
root= tree.getroot()
part000list=[]
for child in root:
    part000list.append(child.text)
finallist=finallist+part000list

tree=ET.parse('bc-cnn-00-cnn_0001-part014_auto_conll_words.xml')
root= tree.getroot()
part000list=[]
for child in root:
    part000list.append(child.text)
finallist=finallist+part000list

tree=ET.parse('bc-cnn-00-cnn_0001-part015_auto_conll_words.xml')
root= tree.getroot()
part000list=[]
for child in root:
    part000list.append(child.text)
finallist=finallist+part000list

tree=ET.parse('bc-cnn-00-cnn_0001-part016_auto_conll_words.xml')
root= tree.getroot()
part000list=[]
for child in root:
    part000list.append(child.text)
finallist=finallist+part000list

tree=ET.parse('bc-cnn-00-cnn_0001-part017_auto_conll_words.xml')
root= tree.getroot()
part000list=[]
for child in root:
    part000list.append(child.text)
finallist=finallist+part000list




len(finallist)
# Out:
# 8689

# %%
df1= pd.DataFrame(np.array(finallist))
df1.columns=['col3']
df1
# Out:
#            col3
# 0        Sunday
# 1           the
# 2     interview
# 3          with
# 4           Bob
# 5       Shapiro
# 6             .
# 7     Newsnight
# 8       returns
# 9            to
# 10          duo
# 11       action
# 12      tonight
# 13            .
# 14          The
# 15     co-hosts
# 16          are
# 17         Kira
# 18     Phillips
# 19          and
# 20         Rick
# 21      Sanchez
# 22            .
# 23         that
# 24           's
# 25         Rick
# 26           on
# 27          the
# 28         left
# 29         Kira
# ...         ...
# 8659    special
# 8660       hour
# 8661         of
# 8662  Newsnight
# 8663    winning
# 8664        the
# 8665        war
# 8666         on
# 8667     terror
# 8668        how
# 8669      other
# 8670    nations
# 8671        are
# 8672   fighting
# 8673  terrorism
# 8674        and
# 8675       what
# 8676         we
# 8677         in
# 8678        the
# 8679         US
# 8680        are
# 8681   learning
# ...

# %%
df= pd.read_csv('cnn_0001.gold_skel.csv')
df.columns=['col0','col1','col2','col3','col4','col5','col6','col7','col8','col9','col9','col10','col11','col12','col13','col14','col15','col16','col17','col18','col19','col20','col21','col22']
df
# Out:
#                     col0  col1  col2    col3 col4                 col5  \
# 0     bc/cnn/00/cnn_0001     0     0  [WORD]  NNP       (TOP(FRAG(NP*)
# 1     bc/cnn/00/cnn_0001     0     1  [WORD]   DT              (NP(NP*
# 2     bc/cnn/00/cnn_0001     0     2  [WORD]   NN                   *)
# 3     bc/cnn/00/cnn_0001     0     3  [WORD]   IN                 (PP*
# 4     bc/cnn/00/cnn_0001     0     4  [WORD]  NNP                 (NP*
# 5     bc/cnn/00/cnn_0001     0     5  [WORD]  NNP                 *)))
# 6     bc/cnn/00/cnn_0001     0     6  [WORD]    .                  *))
# 7     bc/cnn/00/cnn_0001     0     0  [WORD]  NNP          (TOP(S(NP*)
# 8     bc/cnn/00/cnn_0001     0     1  [WORD]  VBZ                 (VP*
# 9     bc/cnn/00/cnn_0001     0     2  [WORD]   IN                 (PP*
# 10    bc/cnn/00/cnn_0001     0     3  [WORD]   JJ                 (NP*
# 11    bc/cnn/00/cnn_0001     0     4  [WORD]   NN                  *))
# ...

# %%
df.update(df1)
df
# Out:
#                     col0  col1  col2       col3 col4                 col5  \
# 0     bc/cnn/00/cnn_0001     0     0     Sunday  NNP       (TOP(FRAG(NP*)
# 1     bc/cnn/00/cnn_0001     0     1        the   DT              (NP(NP*
# 2     bc/cnn/00/cnn_0001     0     2  interview   NN                   *)
# 3     bc/cnn/00/cnn_0001     0     3       with   IN                 (PP*
# 4     bc/cnn/00/cnn_0001     0     4        Bob  NNP                 (NP*
# 5     bc/cnn/00/cnn_0001     0     5    Shapiro  NNP                 *)))
# 6     bc/cnn/00/cnn_0001     0     6          .    .                  *))
# 7     bc/cnn/00/cnn_0001     0     0  Newsnight  NNP          (TOP(S(NP*)
# 8     bc/cnn/00/cnn_0001     0     1    returns  VBZ                 (VP*
# 9     bc/cnn/00/cnn_0001     0     2         to   IN                 (PP*
# 10    bc/cnn/00/cnn_0001     0     3        duo   JJ                 (NP*
# 11    bc/cnn/00/cnn_0001     0     4     action   NN                  *))
# ...
